# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagograsso/matemagica/blob/main/C%C3%B3pia_de_Recupera%C3%A7%C3%A3o_RA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avaliação de Recuperação RA2 - 2024-1
#
# **Antes de começar, leia estas instruções cuidadosamente.**
# Esta avaliação é individual. Você poderá consultar qualquer fonte disponível na biblioteca, suas anotações ou na internet.
#
# **Crie uma cópia deste caderno agora!** E continue lendo as instruções nesta cópia.
#
# **Não existirão prorrogações de prazo de entrega.** Se programe para entregar sua avaliação 5 minutos antes do fim do prazo para evitar imprevistos de última hora.
#
# **Trabalhos idênticos entregues por pessoas, diferentes, serão zerados.** Todos os trabalhos serão submetidos a verificação de plágio. Isso significa que respostas copiadas e coladas de sistemas de inteligência artificial que sejam classificados com semelhança maior que 70% também serão zerados. Qualquer diagnóstico indicativo de plágio acima de 70% também irá provocar o zeramento da avaliação.
#
# Para que sua avaliação seja considerada **ela deve ser entregues em uma cópia deste caderno de atividades na forma de um link postado no AVA da instituição (Canvas)** apenas no local correspondente a essa entrega na avaliação. Qualquer link enviado em comentários, e-mails, mensagens de Whatsapp, ou qualquer outro meio eletrônico serão ignorados provocando o zeramento desta avaliação.
#
# Entrega será realizada com a postagem de um link para um ambiente de execução, no AVA da institução. Neste link o **seu caderno deve permitir ser executado (permissão de leitor)**. Serão aceitos links diretos ao ambiente do Google Colaboratory, ou Links a um caderno do Google Colaboratory que tenha sido **salvo pelo próprio Google Colaboratory** no GitHub. Links para outro ambiente, ou que requeiram qualquer tipo de **download, cliques extras, ou ainda, que requeiram aprovação para acesso, provocarão o zeramento desta avaliação**.
#
# Antes de enviar o seu trabalho, teste o compartilhamento em uma aba anônima do seu navegador web preferido.
#
# Todos os enunciados devem ser preservados e você deverá inserir uma célula de textos com o **seu nome, IMEDIATATAMENTE APÓS esta célula de texto** onde estão estas instruções.
#
# **Qualquer alteração do caderno contendo as suas respostas que seja registrada após a data de postagem provocará a anulação da avaliação**.
#
# Você poderá usar, nas suas respostas, só e somente só, a **linguagem Python** limitada ao uso das seguintes bibliotecas: **math, numpy, sympy, matplotlib, ipWidgets e IPython**. O uso de qualquer biblioteca não listada nestas instruções irá provocar o zeramento da avaliação.
#
# **Todo e qualquer gráfico que usar nas suas respostas deverá ser criado usando o Python**.
#
# **Todas as questões devem ser respondidas em caixas de texto, usando latex para permitir a renderização com qualidade matemática.**
#
# Não é permitido usar qualquer técnica matemática baseada em integração, cálculo numérico, séries de Taylor. de Leibntz, ou de qualquer outro tipo, ou ainda conhecimento matemático que fuja dos conteúdos apresenados em aula referentes ao estudo de limites e derivação.
#
# **Você poderá utilizar técnicas numéicas para calcular máximos, mínimos ou encontrar o polinômio referente a um dado conjunto de pontos. Ainda a sim, sua resposta deve ser explicada em uma caixa de textos, usando latex para as equações matemáticas**
#
# **Esta avaliação está limitada a conteúdo de técnicas, regras e conceitos de derivação**. Porém, pode ocorrer a necessidade do uso dos conceitos e técnicas de limites para a solução das questões.
#
# Se você encontrar algo errado nesta avaliação simplesmente anote suas observações na própria questão. Suas observações serão consideradas durante a avaliação e, em caso de pertinência, poderão encejar a anulação do item, ou questão relacionados a critério do professor.
#
# **ATENÇÃO: SERÃO DESCARTADAS CINCO QUESTÕES ENTRE AS QUE ESTIVEREM ERRADAS, OU QUE FOREM DEIXADAS EM BRANCO. Ou seja, você deve escolher as questões que vai deixar em branco com muito cuidado.**
#
# **ATENÇÃO: TODAS AS QUESTÕES DEVEM SER RESPONDIDAS NA CÉLULA EM BRANCO QUE EXISTE APÓS CADA ENUNCIADO. OS ENUNCIADOS TÊM QUE SER PRESERVADOS E AS QUESTÕES DEVEM SER RESPONDIDAS NA CÉLULA EM BRANCO QUE EXISTE APÓS CADA QUESTÃO.** Se, por algum motivo, ao fazer a cópia deste caderno de questões você perca as células em branco, deve criar uma nova após cada enunciado de questão para colocar sua resposta. Você poderá criar quantas células de texto, ou código, que precisar desde que estas células estejam entre a questão que você está respondendo e a próxima questão deste caderno.
#
# **Esta avaliação valerá, no máximo, 7 pontos como nota final da RA2. Todas as questões tem o mesmo peso.**
#
# **Lembrem-se a interpretação faz parte da questão.**
#
# **Rubrica de Avaliação**: As questões serão consideradas correta se, e somente se, apresentarem a resposta correta, o processo algébrico estiver claro, completo e conciso (nenhuma passagem não explicada), os gráficos contiverem todas as informações necessárias ao seu entendimento.

# %% [markdown]
# **THIAGO GRASSO**

# %% [markdown]
# # Questão 1
#
# (a) Suponha que $ f(x) $ seja uma função de valor real definida para todos os números reais $ x $ em um intervalo aberto cujo centro é um certo número real $ a $. O que significa dizer que $ f $ tem uma derivada $ \frac{d}{dx}(a) $ em $ a $, e qual é o valor de $ \frac{d}{dx}(a) $? (Dê a definição de $ \frac{d}{dx}(a) $.
#
# (b) Use a definição de $ \frac{d}{dx}(a) $ que você acabou de dar na parte (a) para mostrar que se $ f(x) = \frac{1}{2x - 1} $ então $ \frac{d}{dx}(3) = -0.08 $.
#
# (c) Encontre o limite
#
# $$ \lim_{h \to 0} \frac{\sin(\frac{\pi}{6} + h) - (\frac{1}{2})^7}{h} $$

# %% [markdown]
# **(a)** A taxa de variação instantânea da função em $a$ é representada pela derivada de uma função $f(x)$ em um ponto a, que é chamada de $\frac{d}{dx}(a)$. A inclinação da reta tangente ao gráfico da função neste ponto é a derivada em $a$ em geometria. A derivada de $a$ é matematicamente definida como: $$\frac{d}{dx}(a) = \lim_{h \to 0} \frac{f(a + h) - f(h)}{h}$$
# Onde $h$ é uma variação pequena em torno de $a$
#
# **(b)** Apliquemos a definição de derivada para $f(x) = \frac{1}{2}x - 1$, e então vamos calcular \frac{d}{dx}(3). Após a substituição de $a$ por $3$ na definição da derivada, temos:
# $$\frac{d}{dx} = \lim_{h \to 0} \frac{f(3 + h) -f(3)}{h}$$
#
# $$= \frac{\frac{1}{2}(3 + h) - 1 - (\frac{1}{2}(3) - 1)}{h}$$
#
#
# $$= \frac{\frac{1}{2}(3 + h) - \frac{3}{2} + 1}{h}$$
#
# $$= \frac{1}{2}$$
# **Em conclusão, $\frac{d}{dx}(3) = \frac{1}{2}$ ou $0.5$**

# %% [markdown]
# # Questão 2
# Seja $ I $ uma função limitada em $ \mathbb{R} $ e defina $ f $ por $ f(x) = x^2I(x) $. Mostre que $ f $ é diferenciável em $ x = 0 $.

# %% [markdown]
# Para começar, é necessário determinar se o limite $$\lim_{h \to 0}\frac{f(0 + h) - f(0)}{h}$$
# existe; Simplificando a expressão, podemos obter:
# $$\lim_{h \to 0}hI(h)$$
# É possível multiplicar $h$ por $I(h)$ visto que $I(x)$ é limitado em $R $, sem alterar o valor absoluto da expressão.
# Considerando $M$ como uma constante real: $$|hI(h)| ≤ |h|⋅ M$$
# Pelo critério do limite de uma constante multiplicada por uma função que vai para $0$, concluímos que quando $h$ vai para $0$, $|h|⋅M$ vai para $0$, deste modo: $$\lim_{h \to 0}hI(h) = 0$$. **Assim, $f(x) = x^2I(x)$ é de fato diferenciável em $x = 0$**

# %% [markdown]
# # Questão 3
# Use a definição de derivada para encontrar $ \frac{d}{dx}(2) $ para $ f(x) = x + \frac{1}{x} $.

# %% [markdown]
# Aplicando a definição de derivada a $f(x)$ para $x$:
# $$\frac{d}{dx} (x) = 1 $$
# Para $\frac{1}{x}$:
# $$ \frac{d}{dx} \left(\frac{1}{x}\right) = -\frac{1}{x^2} $$
# Somando-as:
# $$f'(x) = 1 - \frac{1}{x^2}$$
# **Logo, $f'(x) = 1 - \frac{1}{x^2}$ é a derivada de $f(x)$ em relação a $x$.**

# %% [markdown]
# # Questão 4
# Se $ g $ é contínua (mas não diferenciável) em $ x = 0 $, $ g(0) = 8 $, e $ f(x) = xg(x) $, encontre $ \frac{d}{dx}(0) $.

# %% [markdown]
# O primeiro passo é substituir o $x$ em $f(x)$ por $0$ e definir a nova expressão:
# $$f(0) = 0 ⋅g(0)=0$$
# Então definimos a derivada de $f(0)$:
# $$f'(0) = \lim_{h \to 0} \frac{f(h) - f(0)}{h} - \lim_{h \to 0} \frac{hg(h) - 0}{h} - \lim_{h \to 0}g(h)$$
# Se $g$ é contínuo em $x-0$:
# $$
# \lim_{h \to 0}g(h) = g(0)$$
# E $g(0) - 8$:
# $$\lim_{h \to 0}g(h) = 8$$
# **A derivada de $f(x)$ em função de $x - 0$ é:**
# $$f'(0) = 8$$

# %% [markdown]
# # Questão 5
# (a) Declare a definição da derivada de $ f(x) $ em $ x = a $.
# (b) Usando a definição da derivada de $ f(x) $ em $ x = 4 $, encontre o valor de $ \frac{d}{dx}(4) $ se $ f(x) = \sqrt{5 - x} $.

# %% [markdown]
# **(a)** O limite da derivada de uma função (f(x)) em um ponto (x = a) é o seguinte:
#
# $$ f'(a) = \lim_{h \to 0} \frac{f(a + h) - f(a)}{h}$$
#
#
# A taxa de variação instantânea da função (f(x)) em relação a (x) no ponto (x = a) é representada nesta definição.
#
# **(b)**
# Primmeiro, encontramos a exprssão de $f(x)$ para o ponto $x = 4$:
# $$ f(4) = \sqrt{5 - 4} = \sqrt{1} = 1 $$
#
# Depois, calculamos a derivada:
# $$f'(4) = \lim_{h \to 0} \frac{f(4 + h) - f(4)}{h}$$
# Simplificar e substituir $f(4)$:
# $$ f'(4) = \lim_{h \to 0} \frac{\sqrt{5 - (4 + h)} - 1}{h}$$
# $$f'(4) = \lim_{h \to 0} \frac{\sqrt{1 - h} - 1}{h}$$
# Racionalizar o numerador:
# $$f'(4) = \lim_{{h \to 0}} \frac{{1 - \sqrt{1 - h}}}{h}$$
# Multiplicar ambos numerador e denomiador por $\sqrt{1 - h} + 1$:
# $$f'(4) = \lim_{{h \to 0}} \frac{1 - (1 - h)}{h(\sqrt{1 - h} + 1)}$$
# $$ f'(4) = \lim_{{h \to 0}} \frac{h}{h(\sqrt{1 - h} + 1)}$$
#  $$ f'(4) = \lim_{{h \to 0}} \frac{1}{\sqrt{1 - h} + 1} = \frac{1}{2} $$
#  **Por fim, temos que $f'(4)$ é igual a $\frac{1}{2}$.**

# %% [markdown]
# # Questão 6
#
# Seja $F$ uma função que é contínua em todos os lugares, defina o valor da sua derivada no ponto em que $F(x)$ corta o eixo $x$
# $$ F(x) =
#    \begin{cases}
#    \frac{f(x) \sin^2 x}{x} & \text{se } x \neq 0, \\
#    0 & \text{se } x = 0.
#    \end{cases}
# $$

# %% [markdown]
# Primeiro devemos avaliar caso o resultado do limite $$\lim_{x \to 0} F(x) = \lim_{x \to 0} \frac{f(x) \sin^2 x}{x}$$ existe e, se sim, se o seu resultado é $0$ em $x = 0$. Se for, $F(x)$ será contínua em $x = 0$ e pode ser  calculada sua derivada:
#  $$F'(0) = \lim_{h \to 0} \frac{F(0 + h) - F(0)}{h}$$
# Substituindo $F(x)$:
# $$F'(0) = \lim_{h \to 0} \frac{\frac{F(h) \sin^2 h}{h} - 0}{h} = \lim_{h \to 0} \frac{F(h) \sin^2 h}{h^2} $$
# **Ou seja, o valor da derivada de $F(x)$ que corta o eixo $x$ é dado por $\lim_{h \to 0} \frac{F(h) \sin^2 h}{h^2}$.**

# %% [markdown]
# # Questão 7
# Deixe $ f(x) = x^2 \sin \left(\frac{1}{x}\right) $ se $ x \neq 0 $, e $ f(0) = 0 $. Encontre $ \frac{d}{dx}(0) $ (ou diga por que ela não existe).

# %% [markdown]
# Primeiro definimos a derivada de $f(x)$ em $x = 0$:
# $$f'(0)= \lim_{h \to 0} \frac{f(0 + h) - f(0)}{h} = \lim_{h \to 0} \frac{f(h)}{h}$$
# Substituir $f(h)$:
# $$f'(0) = \lim_{h \to 0} \frac{h^2 \sin{(\frac{1}{h})}}{h} = \lim_{h \to 0} h \sin{\left(\frac{1}{h}\right)}$$
# Para qualquer $h$ diferente de $0$ no limite acima, $\sin{\left(\frac{1}{h}\right)}$ oscila entre -1 e 1. Logo:
# $$-h ≤ h \sin{\left(\frac{1}{h}\right)}≤h$$
# Quando $h$ se aproxima de $0$, tanto $-h$ como $h$ se aproximam de $0$. Aplicar o Teorema do Confronto à expressão:
# $$\lim_{h \to 0} h \sin{\left(\frac{1}{h}\right)} - 0$$
# $f'(0)$ **existe** e é igual a 0.

# %% [markdown]
# # Questão 8
# Seja $ f(x) = 2x + \cos x $. Diga por que $ f(x) $ é uma função crescente para todo $ x $. Seja $ g(x) = f^{-1}(x) $, e calcule $ g'(0) $.

# %% [markdown]
# Primeiro calculamos a derivada:
# $$f'(x) = 2 - \sin{(x)}$$
# Devido as propriedades de seno, sabemos que $ -1 ≤ \sin{(x)} ≤ 1$ e assim $2 - \sin{(x)} ≥1 $.
#
# Temos que $f(x)$ é **crescente** para todo $x$, pois sua derivada é maior ou igual a $1$.
#
# **Calcular $g'(0)$:**
# Usar a fórmula da derivada de funcção inversa em $ g(x) = f^{-1}(x) $:
# $$g'(y) = \frac{1}{f'(g(y))}$$
# Encontrar valores de $x$ para que $f(x)$ seja igual a $0$ (caso $y = 0$).
# $x = 0$ é uma alternativa:
# $$f(0)=2(0)+\cos{(0)}=1$$
# Temos que $g(0) = 0$, e podemos calcular sua derivada:
# $$g'(0) = \frac{1}{f'(0)}$$
# Como $f'(0) = 2$:
# $$g'(0) = \frac{1}{2}$$
# **O valor de $g'(0)$ é $\frac{1}{2}$ ou $0.5$.**

# %% [markdown]
# # Questão 9
# Mostre que $\frac{d}{dx} (\sin^{-1} x) = \frac{1}{\sqrt{1 - x^2}}$.

# %% [markdown]
# Definimos a derivada:
# $$\lim_{h \to 0} \frac{\sin^{-1}(x + h) - \sin^{-1}(x)}{h}$$
# Simplificar com relação trigonométrica $\sin(\sin^{-1}x) = x$:
# $$\lim_{h \to 0}\frac{\sin^{-1}(x + h) -\sin^{-1}(x)}{\sin(\sin^{-1}(x + h)) - \sin(sin^{-1}(x))} = \frac{\sin^{-1}(x + h) -\sin^{-1}(x)}{(x + h) -x}=\frac{\sin^{-1}(x + h) -\sin^{-1}(x)}{x}$$
#
# Aplicar a expansão em série de Taylor para $\sin^{-1}x$;
#
# E subtrair para ambos os lados $\sin^{-1}(x)$:
# $$\frac{d}{dx}(\sin^{-1}x) = \frac{1}{\sqrt{1 - x^2}}$$
# Logo, a preposição está **correta**.

# %% [markdown]
# # Questão 10
# Suponha que $ f $ é uma função diferenciável tal que $ f(g(x)) = x $, e $ \frac{d}{dx}(x) = \frac{1}{1 + (f(x))^2} $. Mostre que $ g'(x) = \frac{1}{1 + x^2} $.

# %% [markdown]
# É possível usar a Regra da Cadeia para solucionar o problema:
# $$\frac{d}{dx}f(g(x)) = f'(g(x)) \times g'(x)$$
# Diferenciar ambos os lados er relação a $x$, dado que $f(g(x)) = x$:
# $$\frac{d}{dx}x = \frac{d}{dx}f(g(x))$$
# $$1 = f(g(x)) \times g'(x)$$
# $f$ e $g$ são funções inversas, logo podemos inferir que a expressão
# $$f'(g(x)) = \frac{1}{1 + (f(x))^2}$$
# Agora podemos juntar as expressões $f(g(x)) \times g'(x) = 1$ com $f'(g(x))$, deste modo:
# $$\frac{1}{1 + x^2} \times g'(x) = 1$$
# Por fim, isolando $g'(x)$:
# $$g'(x) = \frac{1}{1 + x^2}$$
# **Assim comprovando que a preposição $g'(x) = \frac{1}{1 + x^2}$ é verdadeira**.

# %% [markdown]
# # Questão 11
# Se $ y = \frac{\sqrt{x^2 + 1} - \sqrt{x^2 - 1}}{\sqrt{x^2 + 1} + \sqrt{x^2 - 1}} $, mostre que $\frac{dy}{dx} = \frac{2x^3}{x^4 - 1}$.

# %% [markdown]
# Podemos simplificar a expressão acima, ao intruzir $a = \sqrt{x^2 + 1}$ e $b = \sqrt{x^2 - 1}$. Assim temos:
# $$y = \frac{a - b}{a + b}$$
# É possível obter a derivada de $y$ utilizando a regra do quociente, desta forma:
# $$\frac{dy}{dx} = \frac{2x}{(x^4 - 1)^{\frac{3}{2}}}$$
# Que é a mesma coisa que:
# $$\frac{dy}{dx} = \frac{2x^3}{x^4 - 1}$$
# **Comprovando, por fim, que $\frac{dy}{dx} = \frac{2x^3}{x^4 - 1}$.**

# %% [markdown]
# # Questão 12
# Seja $ f $ uma função diferenciável no $ \mathbb{R} $ e tal que para todo $ x \neq 2 $, $ f(x) = \frac{x^4 - 16}{x - 2} $. Encontre $ f^{(4)}(2) $.

# %% [markdown]
# Primeiro devemos descobrir todas as quatro derivadas possíveis:
# $$f'(x) = 4x^3 - 16$$
# $$f''(x) = 12x^2$$
# $$f'''(x) = 24x$$
# E por fim
# $$f'''' ou f^{(4)}(x) = 24$$
# Depois avaliar $x$ em $2$, **obtendo nosso resultado:**
# $$f^{(4)}(2) = 24$$

# %% [markdown]
# # Questão 13
#
# Dado $ y = \frac{1}{x} + \cos 2x $, encontre $\frac{d^5y}{dx^5}$. Simplifique sua resposta.

# %% [markdown]
# Novamente, descobrimos primeiro todas as derivadas:
# $$\frac{dy}{dx} = - \frac{1}{x^2} - 2\sin{(2x)}$$
# $$\frac{d^2y}{dx^2} = \frac{2}{x^3} - 4\cos{(2x)}$$
# $$\frac{d^3y}{dx^3} = \frac{6}{x^4} - 8\sin{(2x)}$$
# $$\frac{d^4y}{dx^4} = \frac{24}{x^5} - 16\cos{(2x)}$$
# E por fim, **obtemos nossa resposta:**
# $$\frac{d^5y}{dx^5} = \frac{120}{x^6} - 32\sin{(2x)}$$

# %% [markdown]
# # Questão 14
# Encontre os valores de $ A $ e $ B $ que fazem
# $$ f(x) =
#    \begin{cases}
#    x^2 + 1 & \text{se } x \geq 0, \\
#    A \sin x + B \cos x & \text{se } x < 0
#    \end{cases}
# $$
# diferenciável em $ x = 0 $.

# %% [markdown]
# Sendo $f(x)$ contúnua em $x = 0$:
# $$\lim_{x \to 0^-} = \lim_{x \to 0^+} = f(0)$$
# Calcular $f(0)$ usando $f(x)$ para $x \ge 0$:
# $$f(0) = 0^2 + 1 = 1$$
# Limite quando $x$ se aproxima pela esquerda a $0$:
# $$\lim_{x \to 0}(A \sin{x} + B \cos{x}) = A \sin{0} + B \cos{0} = B$$
# Para a função se manter conínua, **$B$ deve ser igual a $1$.**
#
# **Calcular as derivadas de $f(x)$**; para que sejam contínuas, ambas funções dos dois lados de $x = 0$ devem ser iguais:
#
# **Para $x \ge 0$:**
# $$f'(x) = 2x$$
# &
# $$f'(0) = 2 \times 0 = 0$$
#
# **Para $x \lt 0$:**
# $$\frac{d}{dx}(A \sin{x} + B \cos{x}) = A \cos{x} - B \sin{x}$$
#
# Limite da derivada quando $x$ se aproxima pela esquerda a $0$:
# $$\lim_{x \to 0}(A \cos{x} + B \sin{x}) = A \cos{0} + B \sin{0} = A$$
# Para que as derivadas sejam iguais em $x = 0$, **$A$ deve ser igual a $0$**.
#
# **Resultado:**
# **Para que $f(x)$ seja diferenciável em $x = 0$, temos que:**
# $$A = 0$$ **&** $$B = 1$$

# %% [markdown]
# # Questão 15
#
# Uma escada de 15 metros de comprimento está apoiada em uma parede vertical. Seu topo desliza para baixo pela parede enquanto sua base se afasta do solo horizontalmente a uma velocidade de 2 m/s. Com que velocidade o ângulo entre o topo da escada e a parede está mudando quando o ângulo é $\frac{\pi}{3}$ radianos?

# %% [markdown]
# Podemos aplicar o teorema de pitágoras para resolver a questão:
# $$x^2 + y^2 = L^2$$
# Onde $L$ é o comprimento da escada, $15$ metros.
#
# Diferenciar em relação ao tempo:
# $$2x \frac{dx}{dt} + 2y \frac{dy}{dt} = 0$$
#
# Substituir os valores que conhecemos quando $\theta = \frac{\pi}{3}$:
# $$2(6) \cdot 2 + 2(9) \cdot \frac{dy}{dt} = 0$$
#
# Resolver para $\frac{dy}{dt}$:
# $$ \frac{dy}{dt} = -\frac{24}{9} = -\frac{8}{3}$$
# **Por fim, temos que a velocidade em que o ângulo está mudando é de, aproximadamente, $\frac{8}{3}$ radianos por segundo.**6

# %% [markdown]
# # Questão 16
#
# Um foguete $R$ é lançado verticalmente e é rastreado por uma estação de radar $S$ que está a 4 Km de distância do local de lançamento, na mesma altura acima do nível do mar. Em um determinado momento após o lançamento, $R$ está a 5 Km de distância de $S$ e a distância de $R$ para $S$ está aumentando a uma taxa de 3600 Km por hora. Calcule a velocidade vertical $v$ do foguete neste instante.

# %% [markdown]
# Primeiramente estabelecemos alguns parâmetros:
# A aceleração da gravidade é negativa, e a velocidade inicial vertical é positiva, pois o foguete sobe.
# Então aplicar a fórmula da velocidade com base nos dados conhecidos:
# $$ v_y = v_{0y} - g \cdot t$$
# Tendo que no instante descrito a velocidade vertical e a taxa de aumento da disância são iguais:
# $$ v_y = \frac{dd}{dt} = 1000$$
# Em m/s;
# Logo:
# $$v_{0y} = v_y + g \cdot t$$
# Usar a fórmula da velocidade para o lançamento vertical:
# $$ v_y = v_{0y} - g \cdot t $$
# Substituir com os dados conhecidos na expressão:
# $$1000 = v_{0y} - 9,8 \cdot t$$
# Isolar $v_y$
# $$v_{0y} = 1000 + 9,8 \cdot t$$
# Igualar ambas expressões em razão de $v_y$:
# $$ v_{0y} = v_y + g \cdot t $$
# $$1000 + 9,8 \cdot t = v_y + 9,8 \cdot t$$
# $$v_y = 1000$$
# Em m/s;
#
# **Ou seja, temos que a velocidade do foguete no instante é de $1000$m/s.**

# %% [markdown]
# # Questão 17
#
# Um farol está localizado em uma pequena ilha a três (3) km da costa do ponto mais próximo $P$ em uma linha costeira reta. Sua luz faz quatro (4) revoluções por minuto. Com que velocidade o feixe de luz está se movendo ao longo da linha costeira quando ele está iluminando um ponto a um (1) km ao longo da linha costeira a partir de $P$?

# %% [markdown]
# Chamemos o ângulo entre a perpendicular à costa e o ponto em que o feixe de luz incide de $\theta$, e vamos chamar de $x$ a distância entre o ponto da incidência de luz e $P$. A relação entre $\theta$ e $x$ se dá por:
# $$x = 3 \sin(\theta) $$
# Derivar a expressão, considerando que  o cosseno é o cateto adjacente sobre a hipotenusa, e a hipotenusa é a raiz da soma dos quadrados dos catetos: $$\frac{dx}{dt} = 3 \cos(\theta) \frac{d\theta}{dt} $$
# Onde $\frac{d\theta}{dt}$ representa a taxa com que o ângulo $\theta$ varia em radianos por
# uma unidade de tempo.
#
# O farol gira quatro vezes por minuto, dessa forma: $4 \cdot 2\pi$.
#
# Se adotarmos horas como a unidade de tempo e convertermos $4 \cdot 2\pi$ para esta unidade, temos:
# $$\frac{d\theta}{dt} = \frac{4 \cdot 2\pi}{60} = \frac{4\pi}{15} , \text{rad/h}$$
# Substituir os valores com os que conhecemos:
# $$\frac{dx}{dt} = 3 \cos(\theta) \cdot \frac{4\pi}{15}$$
#
# Temos que $x = 1$ quando o feixe de luz incide sobre um ponto a $1$km ao longo da linha costeira partindo de $P$, logo:
# $$1 = 3 \cos(\theta) \cdot \frac{4\pi}{15}$$
# Resolver para $\cos{(\theta)}$:
# $$\cos(\theta) = \frac{5}{12\pi}$$
# Encontrar a taxa de movimento do feixe de luz:
# $$\frac{dx}{dt} = 3 \cdot \frac{5}{12\pi} \cdot \frac{4\pi}{15} = \frac{10}{5} = 2 $$
# Em km/h;
#
# **Finalmente, chegamos a conclusão de que o feixe cd luz se move a $2$km/h ao longo da linha costeira quando ilumina o ponto a $1$ km de distância do ponto $P$**

# %% [markdown]
# # Questão 18
# Um carro de polícia, aproximando-se de um cruzamento em ângulo reto vindo do norte, está perseguindo um SUV em alta velocidade que dobrou a esquina e agora está se movendo diretamente para o leste. Quando o carro de polícia está a 0,6 km ao norte do cruzamento e o SUV está a 0,8 km a leste do cruzamento, a polícia determina por radar que a distância entre eles e o SUV está aumentando a 20 km/h. Se o carro de polícia está se movendo a 60 km/h no instante da medição, qual é a velocidade do SUV?

# %% [markdown]
# Chamamos a distância entre o carro da polícia e o SUV de $d$ e o tempo decorrido desde a medição de $t$. A velocidade do carro da polícia é $v_p = 60$\,km/h, e a velocidade do SUV é $v_s$.
#
# Quando o radar mede a distância, a distância entre eles aumenta a uma taxa de $20$ km/h. isso significa:
#
# $$ \frac{d}{dt} = 20 $$
# Em km/h;
#
# Como o carro da polícia está se movendo para o norte e o SUV está se movendo para o leste, podemos usar o teorema de Pitágoras para relacionar a distância entre eles:
#
# $$ d^2 = 0,6^2 + 0,8^2 $$
# $$ d ^ 2 = 0,36 + 0,64 $$
# $$ d ^ 2 = 1 $$
# $$ d = 1 $$
#
# Derivar ambos os lados da equação em relação ao tempo:
#
# $$\frac{d}{dt} = \frac{d}{dt} \left( \sqrt{(0,6)^2 + (0,8)^2} \right) $$
# $$ 20 = \frac{ 1}{2} \left( \frac{1}{\sqrt{0,36 + 0,64}} \right) \left( 2 \cdot 0,6 \cdot \frac{dd}{dt} + 2 \cdot 0,8 \cdot \ frac{ds}{dt} \right) $$
# $$ 20 = \frac{1}{\sqrt{1}} \left( 0,6 \cdot \frac{dd}{dt} + 0,8 \cdot \frac{ds}{ dt} \right) $$
#  $$ 20 = 0,6 \cdot \frac{dd}{dt} + 0,8 \cdot \frac{ds}{dt} $$
#
# Em seguida, substituir $\frac{dd}{dt} = 20$ para encontrar $\frac{ds}{dt}$:
#
# $$ 20 = 0,6 \cdot 20 + 0,8 \cdot \frac{ds}{dt} $$
# $$ 20 = 12 + 0,8 \cdot \frac{ds}{dt} $$
# $$ 0,8 \cdot \frac{ds}{dt} = 20 - 12 ] [ 0,8 \cdot \frac{ds}{dt} = 8 $$
# $$ \frac{ds}{dt} = \frac{8}{0,8} = 10 $$
#
# **Portanto, a velocidade do SUV é $10$ km/h.**

# %% [markdown]
# # Questão 19
# 1. Esboce o gráfico de $ f(x) = 3x^4 - 8x^3 + 10 $, após responder às seguintes perguntas:
#
#    (a) Onde o gráfico está aumentando e onde está diminuindo?
#
#    (b) Onde o gráfico é côncavo para cima e onde é côncavo para baixo?
#
#    (c) Onde estão os mínimos locais e máximos locais? Estabeleça conclusivamente que são mínimos e máximos locais.
#
#    (d) Onde estão os pontos de inflexão?
#
#    (e) O que acontece com \( f(x) $ à medida que \( x $ tende ao infinito e à medida que $ x $ tende a menos infinito?

# %% [markdown]
# # Questão 20
# 2. Nesta questão, consideramos a função $ f(x) = \frac{x - 3}{\sqrt{x^2 - 9}} $:
#
#    (a) Encontre o domínio de $ f $.
#
#    (b) Encontre as coordenadas de todas as interseções de $ x $ e $ y $, se houver.
#
#    (c) Encontre todas as assíntotas horizontais e verticais, se houver.
#
#    (d) Encontre todos os números críticos, se houver.
#
#    (e) Encontre todos os intervalos nos quais $ f $ está aumentando e aqueles nos quais $ f $ está diminuindo.
#
#    (f) Encontre as coordenadas $ (x, y) $ de todos os pontos máximos e mínimos, se houver.
#
#    (g) Encontre todos os intervalos nos quais $ f $ é côncavo para cima e aqueles nos quais $ f $ é côncavo para baixo.
#
#    (h) Encontre as coordenadas $ (x, y) $ de todos os pontos de inflexão, se houver.
#
#    (i) Esboce o gráfico de $ y = f(x) $ usando todas as informações acima. Todos os pontos relevantes devem ser rotulados.

# %% [markdown]
# # Questão 21
# Encontre as dimensões do retângulo de maior área que tem sua base no eixo x e seus outros dois vértices acima do eixo x e situados na parábola $ y = 12 - x^2 $.

# %% [markdown]
# O primeiro passo é definir os vértices do retângulo:
# Supondo que os vértices do retângulo que estão situados acima do eixo $x$ sejam $(x,y)$ e $(-x,y)$, a base do retângulo estaria entre $x$ e $-y$ no eixo $x$, e teria altura igual a $y$;
# Como os vértices estão descritos na parábola $y = 12 - x^2$, então, expressando $y$ em razão de $x$ temos que o valor de $y$ pode ser escrito da mesma forma: $y = 12 - x^2$;
#
# Encontrar área do retângulo (base $\times$ altura), para base $2x$ e altura $y$:
# $$A(x) = 2x \cdot y = 2x \cdot (12 - x^2) = 24x - 2x^3$$
#
# Encontrar o valor $x$ que maximiza a área:
# Precisamos encontrar os pontos crítics de $A(x)$, derivando-a e igualando a $0$:
# $$A'(x) = \frac{d}{dx}(24x - 2x^3) = 24 - 6x^2$$
# $$24 - 6x^2 = 0$$
# $$4 - x^2 = 0$$
# $$x^2 = 4$$
# $$x = 2 \text{ ou } x = -2 $$
# Porém, como $x$ é a metade da base do retângulo, e a base deve ser um valor positivo, $x = 2$;
#
# **Por fim, basta substituir os valores da base $(2x)$ e altura $(y)$ e teremos nosso resultado:**
#
# **Base:** $2x = 2 \cdot 2 = 4$
#
# **Altura:** $y = 12 - x^2 = 12 - 4 = 8$

# %% [markdown]
# # Questão 22
# Um fazendeiro tem 400 pés de cerca com os quais deseja construir um curral retangular. Ele usará parte de um muro reto existente de 100 pés como um dos lados do perímetro do curral. Qual é a área máxima que pode ser cercada?

# %% [markdown]
# Chamando de $x$ e de $y$ os comprimentos dos lados paralelo ao muro e perpendicular ao muro, respectivamente, podemos primeiro encontrar o perímetro da seguinte forma:
# $$400 = x + 2y$$
# Pois são dois lados perpendiculares e um paralelo. Isolando $x$:
# $$x = 400 - 2y$$
# A área do curral é dada por base $\times$ altura, ou seja, $x \cdot y$. Podemos substituir $x$ na expressão da seguinte forma:
# $$A = x \cdot y = y(400 - 2y)$$
# $$A(y) = 400y - 2y^2$$
#
# Derivar $A(y)$ e igualar a $0$ para encontrar o valor $y$ que maximiza a área:
# $$A'(y) = \frac{d}{dy}(400y - 2y^2) = 400 - 4y$$
# $$400 - 4y = 0$$
# $$100 - y = 0$$
# $$y = 100$$
#
# Agora, substituir $y$ na equação do perímetro:
# $$400 = x + 2 \cdot 100$$
# $$400 = x + 200$$
# $$x = 200$$
#
# **Por fim, calcular a área máxima com $x \times y$, obtendo o resultado:**
# $$x \cdot y = 200 \cdot 100 = 20000 \text{ pés quadrados}$$

# %% [markdown]
# # Questão 23
# Uma escada de $ 10\sqrt{2} $ pés está posicionada a 5 pés de um edifício, veja a Figura 3.4. Encontre o comprimento $ L $ da menor escada, apoiada pelo muro, que alcança do chão ao edifício.

# %% [markdown]
# **REPETIDO**
#
# Podemos aplicar o teorema de pitágoras para resolver o problema, deste modo:
# $$x^2 + y^2 = L^2$$
# Onde $L$ é o comprimento da escada, $10\sqrt{2}$ pés;
#
# $x$ é a distância entre a escada e o edifício, $5$ pés;
#
# E $y$ a altura da escada original na parede.
#
# Substituindo os valores na equação:
# $$5^2 + y^2 = (10\sqrt{2})^2$$
# $$25 + y^2 = 200$$
# $$y^2 = 175$$
# $$y = \sqrt{175} = 5\sqrt{7}$$
#
# **Portanto, o comprimento da escada menor que vai do chão até o prédio é o mesmo de $y$, ou seja, $5\sqrt{7}$.**

# %% [markdown]
# # Questão 24
# Em um campo esportivo elíptico, queremos projetar um campo de futebol retangular com a área máxima possível. O campo esportivo é dado pelo gráfico de $ \frac{x^2}{a^2} + \frac{y^2}{b^2} = 1 $. Encontre o comprimento $ 2x $ e a largura $ 2y $ do campo (em termos de $ a $ e $ b $) que maximizam a área do campo. [Dica: expresse a área do campo como uma função de $ x $ apenas.]

# %% [markdown]
# Primeiro, podemos expressar a área do campo com base $\times$ altura, substituindo pelos dados que temos:
# $$A = \text{base} \times \text{altura} = 2x \cdot 2y = 4xy$$
# Expressar $y$ em razão de $x$ com a equação da elipse:
# $$\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1 \Rightarrow y=b\sqrt{1-\frac{x^2}{a^2}}$$
# Substituir $y$ na fórmula da área:
# $$A = 4x\left(b\sqrt{1-\frac{x^2}{a^2}}\right) = 4bx\left(\sqrt{1-\frac{x^2}{a^2}}\right)$$
# Maximizar a área derivando $A$ em função de $x$:
# $$A'(x) = 4b\left[\sqrt{1-\frac{x^2}{a^2}} + x \cdot \frac{d}{dx}\left(\sqrt{1-\frac{x^2}{a^2}}\right)\right]$$
# Usando a regra do produto e da cadeia;
#
# Resolver a derivada interna:
# $$\frac{d}{dx}\left(\sqrt{1-\frac{x^2}{a^2}}\right) = \frac{1}{2}\left(1 - \frac{x^2}{a^2}\right)^{-\frac{1}{2}} \cdot \left(-\frac{2x}{a^2}\right) = \frac{x}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Substituir em $A'(x)$:
# $$A'(x) = 4b\left[\sqrt{1-\frac{x^2}{a^2}} - \frac{x}{a^2\sqrt{1 - \frac{x^2}{a^2}}}\right] = 4b\frac{a^2(1 - \frac{x^2}{a^2}) - x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Simplificar:
# $$A'(x) = 4b\frac{a^2 - x^2 - x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}} = 4b\frac{a^2 - 2x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Maximizar $A$ igualando $A'(x)$ a $0$:
# $$\frac{a^2 - 2x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}} = 0 \Rightarrow a^2 - 2x^2 = 0 \Rightarrow x^2 = \frac{a^2}{2} \Rightarrow x = \pm \frac{a}{\sqrt{2}}$$
#
# Encontar $y$:
#
# Podemos usar a equação da elipse:
# $$y = b\sqrt{1 - \frac{x^2}{a^2}}$$
#
# $$b \sqrt{1 - \frac{(\frac{a}{\sqrt{2}})^2}{a^2}}$$
#
# $$b \sqrt{1 - \frac{\frac{a^2}{2}}{a^2}}$$
#
# $$b \sqrt{\frac{1}{2}}$$
#
# $$\frac{b}{\sqrt{2}}$$
#
# **Agora podemos descobrir as dimensões do campo para maximizar a área:**
#
# **Comprimento: $$2x = 2 \cdot \frac{a}{\sqrt{2}} = \sqrt{2}a$$**
#
# **Largura: $$2y = 2 \cdot \frac{b}{\sqrt{2}} = \sqrt{2}b$$**

# %% [markdown]
# # Questão 25
# As margens superior e inferior de um pôster são cada uma de 6 cm, e as margens laterais são cada uma de 4 cm. Se a área do material impresso no pôster (isto é, a área entre as margens) é fixada em 384 cm², encontre as dimensões do pôster com a menor área total.

# %% [markdown]
# Sabemos que $x \cdot y = 384$cm$^2$, onde $x$ é a largura e $y$ é a altura.
#
# Como a largura do poster inclui as margens laterias, temos:
# $$x + 2 \cdot 4 = x + 8$$
#
# O mesmo vale para a altura total, porém com as margens superior e inferior:
# $$y + 2 \cdot 6 = y + 12$$
#
# A área total do poster, ou seja, a área entre as margens mais a área das margens, pode ser encontrada por meio da seguinte expressão:
# $$A_t = (x + 8) \cdot (y + 12)$$
#
# Para seguir devemos reduzir a expressão a uma única incógnita. Usaremos $x$.
# Podemos obter isso isolando $y$ em $x \cdot y = 384$, obtendo:
# $$y = \frac{384}{x}$$
#
# Então, substituir $y$ na expressão da área total:
# $$A_t = (x + 8) \cdot (\frac{384}{x} + 12)$$
#
# Após as multiplicações:
# $$A_t = 480 + \frac{3072}{x} + 12x$$
#
# Derivar $A_t$ em função de $x$ para minimizá-la:
# $$\frac{dA_t}{dx} = -\frac{3072}{x^2} + 12$$
#
# Igualar a $0$:
# $$-\frac{3072}{x^2} + 12 = 0$$
# $$x^2 = \frac{3072}{12}$$
# $$x = \sqrt{256} = 16$$
#
# Como sabemos o valor de $x$, podemos encontrar o valor de $y$:
# $$x \cdot y = 384$$
# $$y = \frac{384}{16} = 24$$
#
# **Por fim, com ambos os valores conhecidos, podemos encontrar as dimensões:**
#
# **Largura:**
# $$x + 2 \cdot 4 = x + 8$$
# $$16 + 8$$
# $$24$$
#
# **Altura:**
# $$y + 2 \cdot 6 = y + 12$$
# $$24 + 12$$
# $$36$$

# %% [markdown]
# # Questão 26
#
# 14. Uma escada de $ 10\sqrt{2} $ pés está posicionada a 5 pés de um edifício, veja a figura. Encontre o comprimento $ L $ da menor escada, apoiada na parede, que vai do chão ao edifício.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Podemos aplicar o teorema de pitágoras para resolver o problema, deste modo:
# $$x^2 + y^2 = L^2$$
# Onde $L$ é o comprimento da escada, $10\sqrt{2}$ pés;
#
# $x$ é a distância entre a escada e o edifício, $5$ pés;
#
# E $y$ a altura da escada original na parede.
#
# Substituindo os valores na equação:
# $$5^2 + y^2 = (10\sqrt{2})^2$$
# $$25 + y^2 = 200$$
# $$y^2 = 175$$
# $$y = \sqrt{175} = 5\sqrt{7}$$
#
# **Portanto, o comprimento da escada menor que vai do chão até o prédio é o mesmo de $y$, ou seja, $5\sqrt{7}$.**

# %% [markdown]
# # Questão 27
# Encontre todos os pontos críticos da função $f(x) = |3x -5|$ no intervalo $[−3, 2]$. Encontre também os pontos de máximo e mínimos locais no mesmo intervalo.

# %% [markdown]
# Primeiro, vamos reescrever a expressão, definindo-a em partes:
# $$f(x) = \begin{cases}
# 3x - 5  & \text{se } 3x - 5 \ge 0\\
# -(3x -5) = -3x +5 & \text{se } 3x - 5 \lt 0
# \end{cases}$$
# Simplificando:
# $$f(x) = \begin{cases}
# 3x - 5 & \text{se } x \ge \frac{5}{3} \\
# -3x + 5 & \text{se } x \lt \frac{5}{3}
# \end{cases}$$
#
# Encontrar os pontos críticos:
#
# Existirão quando a derivada de $f(x)$ for inexistente ou igual a $0$ / nula. No caso, teremos duas derivadas diferentes, uma para cada parte de $f(x)$:
# $$f'(x) = 3 \text{, para }(\text{se } x \ge \frac{3}{5})$$
# $$f`(x) = -3 \text{, para }(\text{se } x \lt \frac{5}{3})$$
# Como não são $0$ e constantes, isso indica que os pontos críticos na mudança de definição da função, $x = \frac{5}{3}$.
#
# Para $x = \frac{5}{3}$, a direita $x → (\frac{5}{3})^+$, a derivada é igual a $3$; A esquerda  $x → (\frac{5}{3})^-$, é igual a $-3$.
#
# Portanto, $x = \frac{5}{3}$ é um ponto crítico, já que indica uma mudança de inclinação de $f(x)$.
#
# Calcular valor da função no ponto crítico $x = \frac{5}{3}$ e nos limites do intervalo $[−3, 2]$:
# $$f\left(\frac{5}{3}\right) = 3 \cdot \left(\frac{5}{3}\right) - 5 = 5 - 5 = 0$$
#
# $$f(-3) = 3 \cdot -3 -5 = |-14| = 14$$
#
# $$f(2) = 3 \cdot 2 -5 = |1| = 1$$
#
# **Logo, temos que os pontos críticos são:**
# $$x = \frac{5}{3}$$
# $$x = -3$$
# $$x = 2$$
# **E temso que os pontos de máximo e mínimo são, respectivamente:**
# $$14 \text{ , em } x = -3$$
# $$0 \text{ , em } x = \frac{5}{3}$$

# %% [markdown]
# # Questão 28
#
# Um fazendeiro tem 400 metros de cerca com os quais deseja construir um curral retangular. Ele usará parte de um muro reto existente de 100 metros como um dos lados do perímetro do curral. Qual é a área máxima que pode ser cercada?

# %% [markdown]
# **REPETIDO**
#
# Chamando de $x$ e de $y$ os comprimentos dos lados paralelo ao muro e perpendicular ao muro, respectivamente, podemos primeiro encontrar o perímetro da seguinte forma:
# $$400 = x + 2y$$
# Pois são dois lados perpendiculares e um paralelo. Isolando $x$:
# $$x = 400 - 2y$$
# A área do curral é dada por base $\times$ altura, ou seja, $x \cdot y$. Podemos substituir $x$ na expressão da seguinte forma:
# $$A = x \cdot y = y(400 - 2y)$$
# $$A(y) = 400y - 2y^2$$
#
# Derivar $A(y)$ e igualar a $0$ para encontrar o valor $y$ que maximiza a área:
# $$A'(y) = \frac{d}{dy}(400y - 2y^2) = 400 - 4y$$
# $$400 - 4y = 0$$
# $$100 - y = 0$$
# $$y = 100$$
#
# Agora, substituir $y$ na equação do perímetro:
# $$400 = x + 2 \cdot 100$$
# $$400 = x + 200$$
# $$x = 200$$
#
# **Por fim, calcular a área máxima com $x \times y$, obtendo o resultado:**
# $$x \cdot y = 200 \cdot 100 = 20000 \text{ pés quadrados}$$

# %% [markdown]
# # Questão 29
#
# Em um campo esportivo elíptico, queremos projetar um campo de futebol retangular com a área máxima possível. O campo esportivo é dado pelo gráfico de $ \frac{x^2}{a^2} + \frac{y^2}{b^2} = 1 $. Encontre o comprimento $ 2x $ e a largura $ 2y $ do campo (em termos de $ a $ e $ b $) que maximizam a área do campo. [Dica: expresse a área do campo como uma função de $ x $ apenas.]

# %% [markdown]
# **REPETIDO**
# Primeiro, podemos expressar a área do campo com base $\times$ altura, substituindo pelos dados que temos:
# $$A = \text{base} \times \text{altura} = 2x \cdot 2y = 4xy$$
# Expressar $y$ em razão de $x$ com a equação da elipse:
# $$\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1 \Rightarrow y=b\sqrt{1-\frac{x^2}{a^2}}$$
# Substituir $y$ na fórmula da área:
# $$A = 4x\left(b\sqrt{1-\frac{x^2}{a^2}}\right) = 4bx\left(\sqrt{1-\frac{x^2}{a^2}}\right)$$
# Maximizar a área derivando $A$ em função de $x$:
# $$A'(x) = 4b\left[\sqrt{1-\frac{x^2}{a^2}} + x \cdot \frac{d}{dx}\left(\sqrt{1-\frac{x^2}{a^2}}\right)\right]$$
# Usando a regra do produto e da cadeia;
#
# Resolver a derivada interna:
# $$\frac{d}{dx}\left(\sqrt{1-\frac{x^2}{a^2}}\right) = \frac{1}{2}\left(1 - \frac{x^2}{a^2}\right)^{-\frac{1}{2}} \cdot \left(-\frac{2x}{a^2}\right) = \frac{x}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Substituir em $A'(x)$:
# $$A'(x) = 4b\left[\sqrt{1-\frac{x^2}{a^2}} - \frac{x}{a^2\sqrt{1 - \frac{x^2}{a^2}}}\right] = 4b\frac{a^2(1 - \frac{x^2}{a^2}) - x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Simplificar:
# $$A'(x) = 4b\frac{a^2 - x^2 - x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}} = 4b\frac{a^2 - 2x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}}$$
#
# Maximizar $A$ igualando $A'(x)$ a $0$:
# $$\frac{a^2 - 2x^2}{a^2\sqrt{1 - \frac{x^2}{a^2}}} = 0 \Rightarrow a^2 - 2x^2 = 0 \Rightarrow x^2 = \frac{a^2}{2} \Rightarrow x = \pm \frac{a}{\sqrt{2}}$$
#
# Encontar $y$:
#
# Podemos usar a equação da elipse:
# $$y = b\sqrt{1 - \frac{x^2}{a^2}}$$
#
# $$b \sqrt{1 - \frac{(\frac{a}{\sqrt{2}})^2}{a^2}}$$
#
# $$b \sqrt{1 - \frac{\frac{a^2}{2}}{a^2}}$$
#
# $$b \sqrt{\frac{1}{2}}$$
#
# $$\frac{b}{\sqrt{2}}$$
#
# **Agora podemos descobrir as dimensões do campo para maximizar a área:**
#
# **Comprimento: $$2x = 2 \cdot \frac{a}{\sqrt{2}} = \sqrt{2}a$$**
#
# **Largura: $$2y = 2 \cdot \frac{b}{\sqrt{2}} = \sqrt{2}b$$**

# %% [markdown]
# # Questão 30
# A soma de dois números positivos é $12$. Qual o menor valor possível da soma dos seus quadrados. Justifique sua afirmação algébricamente.

# %% [markdown]
# Podemos representar o problema como:
# $$x + y = 12$$
# &
# $$S = x^2 + y^2$$
# Sendo $S$ o menor valor possível que queremos.
# Resolvendo $x + y = 12$ em função de $y$:
# $$y = 12 - x$$
# Substituir $y$ na expressão de $S$:
# $$S = x^2 + (12 - x)^2$$
# $$S = x^2 + 144 + 24x + x^2$$
# $$S = 2x^2 + 24x + 144$$
#
# A função $S = 2x^2 + 24x + 144$ é uma parábola que abre para cima, pois o coeficiente de $x^2$ é positivo. O valor mínimo da função encontra-se no vértice da parábola. Considerando uma função quadrática $ax^2 + bx +c$, temos que a coordenada $x$ do vértice é:
# $$x = -\frac{b}{2a}$$
# Substituir os valores:
# $$x = -\frac{-24}{2 \cdot 2} = -\frac{-24}{4} = 6$$
# Portanto, $x$ é igual a $6$. Substituindo $x$ em $x + y = 12$, vemos que $y$ também é igual a $6$.
#
# **Logo, para encontrar o resultado basta apenas somar os quadrados:**
# $$S = x^2 + y^2 = 6^2 + 6^2$$
# $$S = 72$$
